# %% [markdown]
# # Chapter 1 - Simple Approaches to Recommender Systems
# ## Segment 2 - Popularity-Based Recommendation

# %%
import pandas as pd
import numpy as np

# %%
np.__version__
# Out:
# '1.14.2'

# %%
frame = pd.read_csv('../Datasets/Rec/rating_final.csv')
cuisine = pd.read_csv('../Datasets/Rec/chefmozcuisine.csv')

# %%
frame.head()
# Out:
#   userID  placeID  rating  food_rating  service_rating
# 0  U1077   135085       2            2               2
# 1  U1077   135038       2            2               1
# 2  U1077   132825       2            2               2
# 3  U1077   135060       1            2               2
# 4  U1068   135104       1            1               2

# %%
cuisine.head()
# Out:
#    placeID        Rcuisine
# 0   135110         Spanish
# 1   135109         Italian
# 2   135107  Latin_American
# 3   135106         Mexican
# 4   135105       Fast_Food

# %%
# Recommending based on counting

# %%
rating_count = pd.DataFrame(frame.groupby('placeID')['rating'].count())
rating_count.sort_values('rating', ascending=False).head()
# Out:
#          rating
# placeID
# 135085       36
# 132825       32
# 135032       28
# 135052       25
# 132834       25

# %%
most_rated_places = pd.DataFrame([125085, 132825,135032,135034, 132834], index=np.arange(5), columns=['placeID'])
pd.merge(most_rated_places, cuisine, on='placeID')
# Out:
#    placeID      Rcuisine
# 0   132825       Mexican
# 1   135032     Cafeteria
# 2   135032  Contemporary
# 3   135034      Japanese
# 4   132834       Mexican

# %%
cuisine['Rcuisine'].describe()
# Out:
# count         916
# unique         59
# top       Mexican
# freq          239
# Name: Rcuisine, dtype: object

# %%
## Segment 3 = Making Recommendations Based on Correlation

#Pearson's Correlation Coefficient - R
# Item based

# %%
import numpy as np
import pandas as pd

# %%
frame = pd.read_csv('../Datasets/Rec2/rating_final.csv',encoding = "ISO-8859-1")
cuisine = pd.read_csv('../Datasets/Rec2/chefmozcuisine.csv',encoding = "ISO-8859-1")
geodata = pd.read_csv('../Datasets/Rec2/geoplaces2.csv',encoding = "ISO-8859-1")

# %%
geodata
# Out:
#      placeID   latitude   longitude  \
# 0     134999  18.915421  -99.184871
# 1     132825  22.147392 -100.983092
# 2     135106  22.149709 -100.976093
# 3     132667  23.752697  -99.163359
# 4     132613  23.752903  -99.165076
# 5     135040  22.135617 -100.969709
# 6     132732  23.754357  -99.171288
# 7     132875  22.149901 -100.993779
# 8     132609  23.760268  -99.165865
# 9     135082  22.151448 -100.915099
# 10    135070  22.152918 -100.915164
# 11    135069  22.140129 -100.944872
# 12    135065  22.149580 -100.999557
# 13    135076  22.181017 -100.973614
# 14    135086  22.141421 -101.013955
# 15    132870  22.143078 -100.935479
# 16    132854  22.137863 -100.938327
# 17    132937  22.150019 -100.979920
# 18    132856  22.151378 -100.974634
# 19    132668  23.738212  -99.151955
# 20    135033  22.141610 -100.973142
# 21    132862  22.150643 -100.987015
# 22    134983  18.948657  -99.235361
# 23    132851  22.136872 -100.934574
# 24    135013  18.917441  -99.165945
# ...
